# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
import pickle

# %%
df = pd.read_csv("E:\\ML\\handsign\\toadotay1.csv", header = None)         #Truy cập file 
df = df.dropna()                                                          #Loại bỏ giá trị thiếu

# %%
df.head()       #5 dòng đầu của file tạo độ
# Out:
#   0    1    2    3         4         5         6         7         8   \
# 0  a  0.0  0.0  0.0 -0.300013 -0.053762 -0.083614 -0.564921 -0.275859
# 1  a  0.0  0.0  0.0 -0.308827 -0.054362 -0.080228 -0.570714 -0.269392
# 2  a  0.0  0.0  0.0 -0.308044 -0.050327 -0.082140 -0.571731 -0.271353
# 3  a  0.0  0.0  0.0 -0.305970 -0.051718 -0.080416 -0.567970 -0.271643
# 4  a  0.0  0.0  0.0 -0.306692 -0.047918 -0.074856 -0.571520 -0.268959
#
#          9   ...        54        55        56        57        58        59  \
# 0 -0.108819  ... -0.045576  0.007307 -0.941054 -0.109625  0.001914 -0.695753
# 1 -0.100963  ... -0.037871  0.015509 -0.937982 -0.099653  0.003229 -0.692945
# 2 -0.100761  ... -0.030863  0.009449 -0.939419 -0.090988 -0.003730 -0.690875
# 3 -0.098466  ... -0.025780  0.008451 -0.936489 -0.084434 -0.006407 -0.689035
# 4 -0.091178  ... -0.029234 -0.003687 -0.938171 -0.088895 -0.015133 -0.690729
#
#          60        61        62        63
# 0 -0.049976  0.018594 -0.609307  0.014511
# 1 -0.038966  0.016414 -0.616490  0.025974
# 2 -0.032597  0.013801 -0.620012  0.029675
# 3 -0.026809  0.012205 -0.616861  0.034806
# 4 -0.031086  0.006644 -0.608747  0.031872
#
# [5 rows x 64 columns]

# %%
x_raw = df.iloc[:, 1:].values                                             #Lấy tất cả giá trị ở cột 1 tới cuối
y_raw = df.iloc[:, 0].values                                              #Lấy tất cả giá trị ở cột 0

# %%
n = np.unique(y_raw)                        #chuyen y_raw thanh numpy

# %%
chuyen_thanh_so = {}                        #chuyen thanh dict {a:1, b:0}
for i,lable in enumerate(n):
    chuyen_thanh_so[lable] = i

# %%
y_list = []                                 #Biến mảng ['a', 'a', 'b'] thành [0, 0, 1]
for key in y_raw:
    value = chuyen_thanh_so[key]
    y_list.append(value)
y_int = np.array(y_list)

# %%
cot = len(n)
onehot = np.zeros((len(y_int), cot))        #tao 1 mang toan 0 voi y_int hang va y_raw cot)
onehot[np.arange(len(y_int)), y_int] = 1    #gan gia tri o hang len(y_int) cot y_int thanh 1

# %%
x_train, x_test, y_train, y_test = train_test_split(x_raw, onehot, test_size=0.2, random_state=42) #chia file train, test

# %%
model = keras.Sequential([                      #tạo khung cho bộ não model
    layers.Input(shape = (63,)),                #tạo input
    layers.Dense(256, activation = 'relu'),     #tạo lớp dense lấy đặc điểm
    layers.Dropout(0.2),                        #tắt ngẫu nhiên 20% no ron ở lớp trên
    layers.Dense(128, activation = 'relu'),
    layers.BatchNormalization(),                #
    layers.Dense(64, activation = 'relu'),      #tổng các các đặc điểm từ lớp dense ở trên
    layers.Dense(len(n), activation = 'softmax')     #tong hop cac lop o tren roi chuyen ket qua ve dang%
])

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics = ['accuracy'])          
model.fit(x_train, y_train, epochs = 15, batch_size = 32, validation_data = (x_test, y_test))
# Out:
# Epoch 1/15
# 648/648 [==============================] - 2s 2ms/step - loss: 0.4070 - accuracy: 0.8965 - val_loss: 0.0398 - val_accuracy: 0.9888
# Epoch 2/15
# 648/648 [==============================] - 1s 2ms/step - loss: 0.0483 - accuracy: 0.9872 - val_loss: 0.0177 - val_accuracy: 0.9965
# Epoch 3/15
# 648/648 [==============================] - 1s 2ms/step - loss: 0.0394 - accuracy: 0.9884 - val_loss: 0.0123 - val_accuracy: 0.9971
# Epoch 4/15
# 648/648 [==============================] - 1s 2ms/step - loss: 0.0352 - accuracy: 0.9888 - val_loss: 0.0111 - val_accuracy: 0.9971
# Epoch 5/15
# 648/648 [==============================] - 1s 2ms/step - loss: 0.0289 - accuracy: 0.9912 - val_loss: 0.0963 - val_accuracy: 0.9741
# Epoch 6/15
# 648/648 [==============================] - 1s 2ms/step - loss: 0.0314 - accuracy: 0.9890 - val_loss: 0.0061 - val_accuracy: 0.9986
# Epoch 7/15
# 648/648 [==============================] - 1s 2ms/step - loss: 0.0195 - accuracy: 0.9939 - val_loss: 0.0051 - val_accuracy: 0.9990
# Epoch 8/15
# 648/648 [==============================] - 1s 2ms/step - loss: 0.0337 - accuracy: 0.9888 - val_loss: 0.0057 - val_accuracy: 0.9994
# Epoch 9/15
# 648/648 [==============================] - 1s 2ms/step - loss: 0.0166 - accuracy: 0.9949 - val_loss: 0.0061 - val_accuracy: 0.9992
# Epoch 10/15
# 648/648 [==============================] - 1s 2ms/step - loss: 0.0246 - accuracy: 0.9922 - val_loss: 0.0094 - val_accuracy: 0.9973
# Epoch 11/15
# 648/648 [==============================] - 1s 2ms/step - loss: 0.0196 - accuracy: 0.9930 - val_loss: 0.0163 - val_accuracy: 0.9948
# Epoch 12/15
# 648/648 [==============================] - 1s 2ms/step - loss: 0.0195 - accuracy: 0.9935 - val_loss: 0.0246 - val_accuracy: 0.9917
# Epoch 13/15
# 648/648 [==============================] - 1s 2ms/step - loss: 0.0173 - accuracy: 0.9950 - val_loss: 0.0068 - val_accuracy: 0.9983
# Epoch 14/15
# 648/648 [==============================] - 1s 2ms/step - loss: 0.0144 - accuracy: 0.9956 - val_loss: 0.0065 - val_accuracy: 0.9988
# Epoch 15/15
# 648/648 [==============================] - 1s 2ms/step - loss: 0.0114 - accuracy: 0.9960 - val_loss: 0.0054 - val_accuracy: 0.9990

# %%
model.save("E:\\ML\\handsign\\models\\model_handsign1.h5")
print("Da luu")
# Out:
# Da luu
